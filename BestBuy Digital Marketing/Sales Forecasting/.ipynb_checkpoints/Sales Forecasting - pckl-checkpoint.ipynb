# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import os
# import boto3
# import pandas as pd
# import sys

# if sys.version_info[0] < 3: 
#     from StringIO import StringIO # Python 2.x
# else:
#     from io import StringIO # Python 3.x

# # get your credentials from environment variables
# aws_id = 'AKIAIS7DC7Q5Y3Q2S23Q'
# aws_secret = 'lQc+hX8UzdrnbjajVR7bDpxHe9XzOyZSUfYe3UOR'

# client = boto3.client('s3', aws_access_key_id=aws_id,
#         aws_secret_access_key=aws_secret)

# bucket_name = 'bestbuyadm'

# object_key = 'adm_project/merge_prod3NaN.csv'
# csv_obj = client.get_object(Bucket=bucket_name, Key=object_key)
# body = csv_obj['Body']
# csv_string = body.read().decode('utf-8')

# df = pd.read_csv(StringIO(csv_string))
# df

# %%
import pandas as pd 
from fbprophet import Prophet
from datetime import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# If you want to use Amazon s3 data use

# %%
df = pd.read_csv('merge_prod3NaN.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'], utc=False)

# %%
df
# Out:
#         Invoice StockCode  Quantity  Price  CustomerID       Date  \
# 0        489434     85048        12   6.95       13085 2017-12-01
# 1        489434    79323P        12   6.75       13085 2017-12-01
# 2        489434    79323W        12   6.75       13085 2017-12-01
# 3        489434     22041        12   2.10       13085 2017-12-01
# 4        489434     21232         2   1.25       13085 2017-12-01
# ...         ...       ...       ...    ...         ...        ...
# 779416   581587     22899         6   2.10       12680 2019-12-09
# 779417   581587     23254         4   4.15       12680 2019-12-09
# 779418   581587     23255         4   4.15       12680 2019-12-09
# 779419   581587     22138         3   4.95       12680 2019-12-09
# 779420   581587      POST         1  18.00       12680 2019-12-09
#
#                                                   Product  UnitPrice  \
# 0       "Samsung QN85Q900TS 85" 8K Ultra High Definiti...   10595.98
# ...

# %%
len(set(df['StockCode']))
# Out:
# 4631

# %%
df.isnull().sum()
# Out:
# Invoice       0
# StockCode     0
# Quantity      0
# Price         0
# CustomerID    0
# Date          0
# Product       0
# UnitPrice     0
# Category      0
# States        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#              Invoice       Quantity          Price     CustomerID  \
# count  779421.000000  779421.000000  779421.000000  779421.000000
# mean   537426.777649       5.378237       3.218487   15320.364902
# std     26901.589183       3.982172      29.676216    1695.691299
# min    489434.000000       1.000000       0.001000   12346.000000
# 25%    514483.000000       2.000000       1.250000   13971.000000
# 50%    536754.000000       4.000000       1.950000   15247.000000
# 75%    561995.000000       9.000000       3.750000   16794.000000
# max    581587.000000      12.000000   10953.500000   18287.000000
#
#            UnitPrice
# count  779421.000000
# mean      961.403052
# std      1436.282028
# min         2.700000
# 25%        54.950000
# 50%       549.990000
# 75%      1142.990000
# max     10595.980000

# %%
df=df[(df['Quantity']>0) & (df['Price']>0)]
df.describe()
# Out:
#              Invoice       Quantity          Price     CustomerID  \
# count  779421.000000  779421.000000  779421.000000  779421.000000
# mean   537426.777649       5.378237       3.218487   15320.364902
# std     26901.589183       3.982172      29.676216    1695.691299
# min    489434.000000       1.000000       0.001000   12346.000000
# 25%    514483.000000       2.000000       1.250000   13971.000000
# 50%    536754.000000       4.000000       1.950000   15247.000000
# 75%    561995.000000       9.000000       3.750000   16794.000000
# max    581587.000000      12.000000   10953.500000   18287.000000
#
#            UnitPrice
# count  779421.000000
# mean      961.403052
# std      1436.282028
# min         2.700000
# 25%        54.950000
# 50%       549.990000
# 75%      1142.990000
# max     10595.980000

# %%
len(set(df['StockCode']))
# Out:
# 4631

# %%
df
# Out:
#         Invoice StockCode  Quantity  Price  CustomerID       Date  \
# 0        489434     85048        12   6.95       13085 2017-12-01
# 1        489434    79323P        12   6.75       13085 2017-12-01
# 2        489434    79323W        12   6.75       13085 2017-12-01
# 3        489434     22041        12   2.10       13085 2017-12-01
# 4        489434     21232         2   1.25       13085 2017-12-01
# ...         ...       ...       ...    ...         ...        ...
# 779416   581587     22899         6   2.10       12680 2019-12-09
# 779417   581587     23254         4   4.15       12680 2019-12-09
# 779418   581587     23255         4   4.15       12680 2019-12-09
# 779419   581587     22138         3   4.95       12680 2019-12-09
# 779420   581587      POST         1  18.00       12680 2019-12-09
#
#                                                   Product  UnitPrice  \
# 0       "Samsung QN85Q900TS 85" 8K Ultra High Definiti...   10595.98
# ...

# %% [markdown]
# # Import Product Data

# %%
df['Daily Sales'] = df['Quantity'] * df['UnitPrice']
df.head()
# Out:
#    Invoice StockCode  Quantity  Price  CustomerID       Date  \
# 0   489434     85048        12   6.95       13085 2017-12-01
# 1   489434    79323P        12   6.75       13085 2017-12-01
# 2   489434    79323W        12   6.75       13085 2017-12-01
# 3   489434     22041        12   2.10       13085 2017-12-01
# 4   489434     21232         2   1.25       13085 2017-12-01
#
#                                              Product  UnitPrice    Category  \
# 0  "Samsung QN85Q900TS 85" 8K Ultra High Definiti...   10595.98  Television
# 1  Samsung QN85Q900TS 8K Ultra High Definition Sm...   10325.98  Television
# 2  Samsung QN85Q900TS 8K Ultra High Definition Sm...   10275.98  Television
# 3  SunBrite 75" Outdoor TV 4K HDR - Signature 2 S...    9999.00  Television
# 4  SunBrite 75" Outdoor TV 4K HDR - Signature 2 S...    9999.00  Television
#
#   States  Daily Sales
# 0     MS    127151.76
# 1     WY    123911.76
# 2     WI    123311.76
# 3     MS    119988.00
# 4     LA     19998.00

# %%
df_daily_sales = df.groupby('Date')['Daily Sales'].sum().reset_index()

# %%
# df_daily_sales2 = df_daily_sales[:-40]

# %%
# df_daily_sales2

# %%
df_daily_sales = df_daily_sales[:-10]

# %%
df_daily_sales
# Out:
#             Daily Sales
# Date
# 2017-12-01  24237989.78
# 2017-12-02  16059054.64
# 2017-12-03  20928109.38
# 2017-12-04  14938811.31
# 2017-12-05   5807128.90
# ...                 ...
# 2019-11-23  12117141.44
# 2019-11-24   8928547.09
# 2019-11-25   5774891.43
# 2019-11-27   4615190.85
# 2019-11-28   9745897.73
#
# [594 rows x 1 columns]

# %%
df_daily_sales = df_daily_sales.set_index('Date')

# %%
df_daily_sales
# Out:
#             Daily Sales
# Date
# 2017-12-01  24237989.78
# 2017-12-02  16059054.64
# 2017-12-03  20928109.38
# 2017-12-04  14938811.31
# 2017-12-05   5807128.90
# ...                 ...
# 2019-12-05  11616791.98
# 2019-12-06   9824110.73
# 2019-12-07   9276572.65
# 2019-12-08   8375659.98
# 2019-12-09   2741051.10
#
# [604 rows x 1 columns]

# %%
# df2 = df_daily_sales[df_daily_sales['Date']<]

# %%
daily_df = df_daily_sales.resample('D').mean()

# %%
daily_df
# Out:
#             Daily Sales
# Date
# 2017-12-01  24237989.78
# 2017-12-02  16059054.64
# 2017-12-03  20928109.38
# 2017-12-04  14938811.31
# 2017-12-05   5807128.90
# ...                 ...
# 2019-11-24   8928547.09
# 2019-11-25   5774891.43
# 2019-11-26          NaN
# 2019-11-27   4615190.85
# 2019-11-28   9745897.73
#
# [728 rows x 1 columns]

# %%
# daily_df.to_csv("daily_df.csv")

# %%
d_df = daily_df.reset_index().dropna()

# %%
d_df.columns = ['ds', 'y']
fig = plt.figure(facecolor='w', figsize=(20, 6))
plt.plot(d_df.ds, d_df.y)

# %%
m = Prophet()
m.fit(d_df)
future = m.make_future_dataframe(periods=30)
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#             ds          yhat    yhat_lower    yhat_upper
# 619 2019-12-24  5.074984e+06  1.970156e+06  8.254238e+06
# 620 2019-12-25  7.151786e+06  4.288422e+06  1.033041e+07
# 621 2019-12-26  8.563318e+06  5.620361e+06  1.193552e+07
# 622 2019-12-27  8.724587e+06  5.949597e+06  1.170297e+07
# 623 2019-12-28  8.487105e+06  5.458037e+06  1.141840e+07

# %%
forecast.to_csv('SaleForecast.csv')

# %%
import pickle
with open('forecast_model.pckl', 'wb') as fout:
    pickle.dump(m, fout)

# %%
period = (df['Date'].max()-df['Date'].min()).days

# %%
period
# Out:
# 738

# %%
from datetime import datetime, timedelta
fig1 = m.plot(forecast)
#datenow = datetime.now()
datenow = datetime(2019,11,28)
dateend = datenow + timedelta(days=30)
datestart = dateend - timedelta(days=700)
plt.xlim([datestart, dateend])
plt.title("Iron/steel forecast", fontsize=20)
plt.xlabel("Day", fontsize=20)
plt.ylabel("Iron/steel price", fontsize=20)
plt.axvline(datenow, color="k", linestyle=":")
plt.show()

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']][-7:]
# Out:
#             ds          yhat    yhat_lower    yhat_upper
# 617 2019-12-22  9.899557e+06  6.748872e+06  1.279097e+07
# 618 2019-12-23  7.402057e+06  4.472855e+06  1.036751e+07
# 619 2019-12-24  5.074984e+06  1.970156e+06  8.254238e+06
# 620 2019-12-25  7.151786e+06  4.288422e+06  1.033041e+07
# 621 2019-12-26  8.563318e+06  5.620361e+06  1.193552e+07
# 622 2019-12-27  8.724587e+06  5.949597e+06  1.170297e+07
# 623 2019-12-28  8.487105e+06  5.458037e+06  1.141840e+07

# %%
fig2 = m.plot_components(forecast)

# %%
from fbprophet.diagnostics import cross_validation, performance_metrics
df_cv = cross_validation(m, horizon='90 days')
df_p = performance_metrics(df_cv)
df_p.head(5)
# Out:
# INFO:fbprophet:Making 9 forecasts with cutoffs between 2018-09-04 00:00:00 and 2019-08-30 00:00:00
#   horizon           mse          rmse           mae      mape     mdape  \
# 0  9 days  6.289291e+12  2.507846e+06  1.998475e+06  0.384254  0.262026
# 1 10 days  6.274278e+12  2.504851e+06  2.011378e+06  0.368207  0.262026
# 2 11 days  6.554357e+12  2.560148e+06  2.068848e+06  0.384250  0.282900
# 3 12 days  6.444745e+12  2.538650e+06  2.020036e+06  0.361362  0.267212
# 4 13 days  6.278136e+12  2.505621e+06  2.035089e+06  0.368347  0.295497
#
#    coverage
# 0  0.804924
# 1  0.789773
# 2  0.772727
# 3  0.782197
# 4  0.757576

# %%
from fbprophet.plot import plot_cross_validation_metric
fig3 = plot_cross_validation_metric(df_cv, metric='mape')
